# %% [markdown]
# # **ASSIGNMENT-1**

# %%
bank = [
    [
        [
            ["C101", "Rahul", "Savings", 85000],
            ["C102", "Anita", "Current", 150000],
            ["C103", "Kiran", "Loan", 500000]
        ],
        [
            ["C104", "Sneha", "Savings", 95000],
            ["C105", "Vikram", "Current", 275000],
            ["C106", "Meena", "Loan", 750000]
        ]
    ],

    [
        [
            ["C201", "Arjun", "Savings", 120000],
            ["C202", "Pooja", "Current", 325000],
            ["C203", "Ramesh", "Loan", 900000]
        ],
        [
            ["C204", "Priya", "Savings", 45000],
            ["C205", "Amit", "Current", 185000],
            ["C206", "Divya", "Loan", 650000]
        ]
    ],

    [
        [
            ["C301", "Nikhil", "Savings", 78000],
            ["C302", "Kavya", "Current", 240000],
            ["C303", "Suresh", "Loan", 1000000]
        ],
        [
            ["C304", "Neha", "Savings", 135000],
            ["C305", "Rohan", "Current", 410000],
            ["C306", "Asha", "Loan", 550000]
        ]
    ]
]

# %% [markdown]
# 1. Print Rahul's complete record.
#    ```
#    Answer:bank[0][0][0]
#
#          ['C101', 'Rahul', 'Savings', 85000]
#    ```
# 2. Print Anita's account type.
#    ```
#    Answer:bank[0][0][1][2]
#
#           Current
#    ```
#
# 3. Print Kiran's loan amount.
#    ```
#    Answer:bank[0][0][2][3]
#
#           500000
#    ```
#
# 4. Print Sneha's customer ID.
#    ```
#    Answer:bank[0][1][0][0]
#
#           C104
#    ```
#
# 5. Print Vikram's balance.
#    ```
#    Answer:bank[0][1][1][3]
#
#           275000
#    ```
#
# 6. Print Meena's complete record.
#    ```
#    Answer:bank[0][1][2]
#
#           ['C106', 'Meena', 'Loan', 750000]
#    ```
#
# 7. Print Arjun's customer ID.
#    ```
#    Answer:bank[1][0][0][0]
#
#           C201
#    ```
#
# 8. Print Pooja's name.
#    ```
#    Answer:bank[1][0][1][1]
#
#           Pooja
#    ```
#
# 9. Print Ramesh's account type.
#    ```
#    Answer:bank[1][0][2][2]
#
#           Loan
#    ```
#
# 10. Print Priya's balance.
#    ```
#    Answer:bank[1][1][0][3]
#
#           45000
#    ```
# 11. Print Amit's account type.
#    ```
#    Answer:bank[1][1][1][2]
#
#           Current
#    ```
# 12. Print Divya's customer ID.
#    ```
#    Answer:bank[1][1][2][0]
#
#           C206
#    ```
# 13. Print Nikhil's account type.
#    ```
#    Answer:bank[2][0][0][2]
#
#           Savings
#    ```
# 14. Print Kavya's balance.
#    ```
#    Answer:bank[2][0][1][3]
#
#           240000
#    ```
# 15. Print Suresh's loan amount.
#    ```
#    Answer:bank[2][0][2][3]
#
#           1000000
#    ```
# 16. Print Neha's name.
#    ```
#    Answer:bank[2][1][0][1]
#
#           Neha
#    ```
# 17. Print Rohan's complete record.
#    ```
#    Answer:bank[2][1][1]
#
#           ['C305', 'Rohan', 'Current', 410000]
#    ```
# 18. Print Asha's account type.
#    ```
#    Answer:bank[2][1][2][2]
#
#           Loan
#    ```
# 19. Print all customers in Bank 1, Branch 1.
#    ```
#    Answer:bank[0][0]
#
#           [['C101', 'Rahul', 'Savings', 85000],
#            ['C102', 'Anita', 'Current', 150000],
#            ['C103', 'Kiran', 'Loan', 500000]]
#    ```
# 20. Print all customers in Bank 1, Branch 2.
#    ```
#    Answer:bank[0][1]
#
#           [['C104', 'Sneha', 'Savings', 95000],
#            ['C105', 'Vikram', 'Current', 275000],
#            ['C106', 'Meena', 'Loan', 750000]]
#    ```
# 21. Print all customers in Bank 2, Branch 1.
#    ```
#    Answer:bank[1][0]
#
#           [['C201', 'Arjun', 'Savings', 120000],
#            ['C202', 'Pooja', 'Current', 325000],
#            ['C203', 'Ramesh', 'Loan', 900000]]
#    ```
# 22. Print all customers in Bank 2, Branch 2.
#    ```
#    Answer:bank[1][1]
#
#           [['C204', 'Priya', 'Savings', 45000],
#            ['C205', 'Amit', 'Current', 185000],
#            ['C206', 'Divya', 'Loan', 650000]]
#    ```
# 23. Print all customers in Bank 3, Branch 1.
#    ```
#    Answer:bank[2][0]
#
#           [['C301', 'Nikhil', 'Savings', 78000],
#            ['C302', 'Kavya', 'Current', 240000],
#            ['C303', 'Suresh', 'Loan', 1000000]]
#    ```
# 24. Print all customers in Bank 3, Branch 2.
#    ```
#    Answer:bank[2][1]
#
#          [['C304', 'Neha', 'Savings', 135000],
#           ['C305', 'Rohan', 'Current', 410000],
#           ['C306', 'Asha', 'Loan', 550000]]
#    ```
# 25. Print all branches of Bank 1.
#    ```
#    Answer:bank[0]
#
#           [[['C101', 'Rahul', 'Savings', 85000],
#             ['C102', 'Anita', 'Current', 150000],
#             ['C103', 'Kiran', 'Loan', 500000]],
#            [['C104', 'Sneha', 'Savings', 95000],
#             ['C105', 'Vikram', 'Current', 275000],
#             ['C106', 'Meena', 'Loan', 750000]]]
#    ```
# 26. Print all branches of Bank 2.
#    ```
#    Answer:bank[1]
#           [[['C201', 'Arjun', 'Savings', 120000],
#             ['C202', 'Pooja', 'Current', 325000],
#             ['C203', 'Ramesh', 'Loan', 900000]],
#            [['C204', 'Priya', 'Savings', 45000],
#             ['C205', 'Amit', 'Current', 185000],
#            ['C206', 'Divya', 'Loan', 650000]]]
#    ```
# 27. Print all branches of Bank 3.
#    ```
#    Answer:bank[2]
#           [[['C301', 'Nikhil', 'Savings', 78000],
#             ['C302', 'Kavya', 'Current', 240000],
#             ['C303', 'Suresh', 'Loan', 1000000]],
#            [['C304', 'Neha', 'Savings', 135000],
#             ['C305', 'Rohan', 'Current', 410000],
#             ['C306', 'Asha', 'Loan', 550000]]]
#    ```
# 28. Print the first customer from every bank's first branch.
#    ```
#    Answer:print(bank[0][0][0])
#           print(bank[1][0][0])
#           print(bank[2][0][0])
#
#           ['C101', 'Rahul', 'Savings', 85000]
#           ['C201', 'Arjun', 'Savings', 120000]
#           ['C301', 'Nikhil', 'Savings', 78000]
#    ```
# 29. Print the second customer from every bank's second branch.
#    ```
#    Answer:print(bank[0][1][1])
#           print(bank[1][1][1])
#           print(bank[2][1][1])
#
#           ['C105', 'Vikram', 'Current', 275000]
#           ['C205', 'Amit', 'Current', 185000]
#           ['C305', 'Rohan', 'Current', 410000]
#    ```
# 30. Print the loan amount of the last customer in Bank 3, Branch 2.
#    ```
#    Answer:bank[2][1][2][3]
#
#           550000
#    ```

# %%
bank[0][0][0]
# Out:
# ['C101', 'Rahul', 'Savings', 85000]

# %%
bank[0][0][1][2]
# Out:
# 'Current'

# %%
bank[0][0][2][3]
# Out:
# 500000

# %%
bank[0][1][0][0]
# Out:
# 'C104'

# %%
bank[0][1][1][3]
# Out:
# 275000

# %%
bank[0][1][2]
# Out:
# ['C106', 'Meena', 'Loan', 750000]

# %%
bank[1][0][0][0]
# Out:
# 'C201'

# %%
bank[1][0][1][1]
# Out:
# 'Pooja'

# %%
bank[1][0][2][2]
# Out:
# 'Loan'

# %%
bank[1][1][0][3]
# Out:
# 45000

# %%
bank[1][1][1][2]
# Out:
# 'Current'

# %%
bank[1][1][2][0]
# Out:
# 'C206'

# %%
bank[2][0][0][2]
# Out:
# 'Savings'

# %%
bank[2][0][1][3]
# Out:
# 240000

# %%
bank[2][0][2][3]
# Out:
# 1000000

# %%
bank[2][1][0][1]
# Out:
# 'Neha'

# %%
bank[2][1][1]
# Out:
# ['C305', 'Rohan', 'Current', 410000]

# %%
bank[2][1][2][2]
# Out:
# 'Loan'

# %%
bank[0][0]
# Out:
# [['C101', 'Rahul', 'Savings', 85000],
#  ['C102', 'Anita', 'Current', 150000],
#  ['C103', 'Kiran', 'Loan', 500000]]

# %%
bank[0][1]
# Out:
# [['C104', 'Sneha', 'Savings', 95000],
#  ['C105', 'Vikram', 'Current', 275000],
#  ['C106', 'Meena', 'Loan', 750000]]

# %%
bank[1][0]
# Out:
# [['C201', 'Arjun', 'Savings', 120000],
#  ['C202', 'Pooja', 'Current', 325000],
#  ['C203', 'Ramesh', 'Loan', 900000]]

# %%
bank[1][1]
# Out:
# [['C204', 'Priya', 'Savings', 45000],
#  ['C205', 'Amit', 'Current', 185000],
#  ['C206', 'Divya', 'Loan', 650000]]

# %%
bank[2][0]
# Out:
# [['C301', 'Nikhil', 'Savings', 78000],
#  ['C302', 'Kavya', 'Current', 240000],
#  ['C303', 'Suresh', 'Loan', 1000000]]

# %%
bank[2][1]
# Out:
# [['C304', 'Neha', 'Savings', 135000],
#  ['C305', 'Rohan', 'Current', 410000],
#  ['C306', 'Asha', 'Loan', 550000]]

# %%
bank[0]
# Out:
# [[['C101', 'Rahul', 'Savings', 85000],
#   ['C102', 'Anita', 'Current', 150000],
#   ['C103', 'Kiran', 'Loan', 500000]],
#  [['C104', 'Sneha', 'Savings', 95000],
#   ['C105', 'Vikram', 'Current', 275000],
#   ['C106', 'Meena', 'Loan', 750000]]]

# %%
bank[1]
# Out:
# [[['C201', 'Arjun', 'Savings', 120000],
#   ['C202', 'Pooja', 'Current', 325000],
#   ['C203', 'Ramesh', 'Loan', 900000]],
#  [['C204', 'Priya', 'Savings', 45000],
#   ['C205', 'Amit', 'Current', 185000],
#   ['C206', 'Divya', 'Loan', 650000]]]

# %%
bank[2]
# Out:
# [[['C301', 'Nikhil', 'Savings', 78000],
#   ['C302', 'Kavya', 'Current', 240000],
#   ['C303', 'Suresh', 'Loan', 1000000]],
#  [['C304', 'Neha', 'Savings', 135000],
#   ['C305', 'Rohan', 'Current', 410000],
#   ['C306', 'Asha', 'Loan', 550000]]]

# %%
print(bank[0][0][0])
print(bank[1][0][0])
print(bank[2][0][0])
# Out:
# ['C101', 'Rahul', 'Savings', 85000]
# ['C201', 'Arjun', 'Savings', 120000]
# ['C301', 'Nikhil', 'Savings', 78000]

# %%
print(bank[0][1][1])
print(bank[1][1][1])
print(bank[2][1][1])
# Out:
# ['C105', 'Vikram', 'Current', 275000]
# ['C205', 'Amit', 'Current', 185000]
# ['C305', 'Rohan', 'Current', 410000]

# %%
bank[2][1][2][3]
# Out:
# 550000

# %% [markdown]
# 1. Create a list of 5 employee names and add a new employee using `append()`.
#  ```
#    Answer:employees=['leela','sunil','pavan',   'kumar','royal']
#           employees.append('vishnu')
#           print(employees)
#
#           ['leela', 'sunil', 'pavan', 'kumar', 'royal', 'vishnu']
#    ```
# 2. Create a list of account numbers and add three new account numbers using `extend()`.
# ```
#    Answer:account numbers=['C101','C102','C103']
#           account numbers.extend(['C104','C105','C106'])
#           print(account numbers)
#
#           ['C101', 'C102', 'C103', 'C104', 'C105', 'C106']
#    ```
# 3. Insert a new customer at the beginning of a customer list using `insert()`.
# ```
#    Answer:customers=['leela','sunil','pavan','kumar','royal']
#           customers.insert(0, 'rahul')
#           print(customers)
#
#           ['rahul', 'leela', 'sunil', 'pavan', 'kumar', 'royal']
#    ```
# 4. Insert a transaction amount at index 3 in a list.
# ```
#    Answer:transactions=[1000,2000,4000,5000,6000]
#           transactions.insert(3,"3000")
#           print(transactions)
#
#           [1000, 2000, 4000, '3000', 5000, 6000]
#    ```
# 5. Remove the last item from a list using `pop()`.
# ```
#    Answer:list_item=['banana','mango','apple','grapes','orange']
#           list_item.pop(4)
#           print(list_item)
#
#           ['banana', 'mango', 'apple', 'grapes']
#    ```
# 6. Remove the customer "Rahul" from a customer list using `remove()`.
# ```
#    Answer:customer=['leela','rahul','pavan','kumar','royal']
#           customer.remove('rahul')
#           print(x)
#
#           ['leela', 'pavan', 'kumar', 'royal']
#    ```
# 7. Count how many times the account type "Savings" appears in a list using `count()`.
# ```
#    Answer:account_types=["Savings","Current","Savings","loan","Savings"]
#           print(account_types.count("Savings"))
#
#           3
#    ```
# 8. Find the index of "Current" in a list of account types using `index()`.
# ```
#    Answer:account_types=["Savings","Current","Loan"]
#           print(account_types.index("Current"))
#
#           1
#    ```
# 9. Reverse a list of transaction IDs using `reverse()`.
# ```
#    Answer:transaction_IDs=[101,102,103,104,105,106]
#           transaction_IDs.reverse()
#           print(transaction_IDs)
#
#           [106, 105, 104, 103, 102, 101]
#    ```
# 10. Sort a list of account balances in ascending order using `sort()`.
# ```
#    Answer:balances=[5000,160000,85000,9000,25000]
#           balances.sort()
#           print(balances)
#
#           [5000, 9000, 25000, 85000, 160000]
#    ```
# 11. Sort a list of customer names in descending order using `sort()`.
# ```
#    Answer:customers=["leela","pavan","kumar","rahul","vishal"]
#           customers.sort(reverse=True)
#           print(customers)
#
#           ['vishal', 'rahul', 'pavan', 'leela', 'kumar']
#    ```
# 12. Make a copy of a list using `copy()` and verify that modifying the copied list does not affect the original list.
# ```
#    Answer:customers=["leela","rahul","vishal"]
#           copy_customers=customers.copy()
#           print("Original:",customers)
#           print("Copy:",copy_customers)
#
#           Original: ['leela', 'rahul', 'vishal']
#           Copy: ['leela', 'rahul', 'vishal']
#    ```
# 13. Clear all elements from a list using `clear()`.
# ```
#    Answer:customers=["leela","rahul","vishal"]
#           customers.clear()
#           print(customers)
#
#           []
#    ```
# 14. Append a nested list containing a new customer's details to an existing customer list.
# ```
#    Answer:customers=["C101","leela","Savings",85000]
#           customers.append(["C102","rahul","Current",150000])
#           print(customers)
#
#           ['C101', 'leela', 'Savings', 85000, ['C102', 'rahul', 'Current', 150000]]
#    ```
# 15. Extend a list of branch names with another list of new branches.
# ```
#    Answer:branches=["ngo colony","Indira Nagar",]
#           new_branches=["White Field","Electronic City"]
#           branches.extend(new_branches)
#           print(branches)
#
#           ['ngo colony', 'Indira Nagar', 'White Field', 'Electronic City']
#    ```
# 16. Remove the first occurrence of the balance `50000` from a list using `remove()`.
# ```
#    Answer:balances=[50000,15000,50000,160000]
#           balances.remove(50000)
#           print(balances)
#
#           [15000, 50000, 160000]
#    ```
# 17. Pop the element at index 2 from a list and print the removed value.
# ```
#    Answer:numbers=[100,200,300,400,500]
#           removed=numbers.pop(3)
#           print("Removed:",removed)
#           print(numbers)
#
#           Removed: 400
#          [100, 200, 300, 500]
#    ```
# 18. Count how many times the city "Bangalore" appears in a list.
# ```
#    Answer:cities=["Banglore","Hyderabad","Banglore","Chennai","Banglore"]
#          print(cities.count("Banglore"))
#
#          3
#    ```
# 19. Reverse a list of bank names and print the result.
# ```
#    Answer:banks=["SBI","HDFC","ICICI","AXIS"]
#           banks.reverse()
#           print(banks)
#
#           ['AXIS', 'ICICI', 'HDFC', 'SBI']
#    ```
# 20. Create a list of loan amounts and sort it in descending order.
# ```
#    Answer:loan_amounts=[800000,1600000,290000,1500000]
#           loan_amounts.sort(reverse=True)
#           print(loan_amounts)
#
#           [1600000, 1500000, 800000, 290000]
#    ```

# %%
employees=['leela','sunil','pavan','kumar','royal']
employees.append('vishnu')
print(employees)
# Out:
# ['leela', 'sunil', 'pavan', 'kumar', 'royal', 'vishnu']

# %%
account_numbers=['C101','C102','C103']
account_numbers.extend(['C104','C105','C106'])
print(account_numbers)
# Out:
# ['C101', 'C102', 'C103', 'C104', 'C105', 'C106']

# %%
customers=['leela','sunil','pavan','kumar','royal']
customers.insert(0, 'rahul')
print(customers)
# Out:
# ['rahul', 'leela', 'sunil', 'pavan', 'kumar', 'royal']

# %%
transactions=[1000,2000,4000,5000,6000]
transactions.insert(3,"3000")
print(transactions)
# Out:
# [1000, 2000, 4000, '3000', 5000, 6000]

# %%
list_item=['banana','mango','apple','grapes','orange']
list_item.pop(4)
print(list_item)
# Out:
# ['banana', 'mango', 'apple', 'grapes']

# %%
customer=['leela','rahul','pavan','kumar','royal']
customer.remove('rahul')
print(customer)
# Out:
# ['leela', 'pavan', 'kumar', 'royal']

# %%
account_types=["Savings","Current","Savings","loan","Savings"]
print(account_types.count("Savings"))
# Out:
# 3

# %%
account_types=["Savings","Current","Loan"]
print(account_types.index("Current"))
# Out:
# 1

# %%
transaction_IDs=[101,102,103,104,105,106]
transaction_IDs.reverse()
print(transaction_IDs)
# Out:
# [106, 105, 104, 103, 102, 101]

# %%
balances=[5000,160000,85000,9000,25000]
balances.sort()
print(balances)
# Out:
# [5000, 9000, 25000, 85000, 160000]

# %%
customers=["leela","pavan","kumar","rahul","vishal"]
customers.sort(reverse=True)
print(customers)
# Out:
# ['vishal', 'rahul', 'pavan', 'leela', 'kumar']

# %%
customers=["leela","rahul","vishal"]
copy_customers=customers.copy()
print("Original:",customers)
print("Copy:",copy_customers)
# Out:
# Original: ['leela', 'rahul', 'vishal']
# Copy: ['leela', 'rahul', 'vishal']

# %%
customers=["leela","rahul","vishal"]
customers.clear()
print(customers)
# Out:
# []

# %%
customers=["C101","leela","Savings",85000]
customers.append(["C102","rahul","Current",150000])
print(customers)
# Out:
# ['C101', 'leela', 'Savings', 85000, ['C102', 'rahul', 'Current', 150000]]

# %%
branches=["ngo colony","Indira Nagar",]
new_branches=["White Field","Electronic City"]
branches.extend(new_branches)
print(branches)
# Out:
# ['ngo colony', 'Indira Nagar', 'White Field', 'Electronic City']

# %%
balances=[50000,15000,50000,160000]
balances.remove(50000)
print(balances)
# Out:
# [15000, 50000, 160000]

# %%
numbers=[100,200,300,400,500]
removed=numbers.pop(3)
print("Removed:",removed)
print(numbers)
# Out:
# Removed: 400
# [100, 200, 300, 500]

# %%
cities=["Banglore","Hyderabad","Banglore","Chennai","Banglore"]
print(cities.count("Banglore"))
# Out:
# 3

# %%
banks=["SBI","HDFC","ICICI","AXIS"]
banks.reverse()
print(banks)
# Out:
# ['AXIS', 'ICICI', 'HDFC', 'SBI']

# %%
loan_amounts=[800000,1600000,290000,1500000]
loan_amounts.sort(reverse=True)
print(loan_amounts)
# Out:
# [1600000, 1500000, 800000, 290000]
