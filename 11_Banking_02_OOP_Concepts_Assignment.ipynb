# %% [markdown]
# # Banking Assignment — Object-Oriented Programming (100 Questions with Hints)
#
# An unsolved assessment notebook using accounts, deposits, withdrawals, transfers, cards, loans, KYC, fraud monitoring, reconciliation, and audit trails.
#
# **Structure:** 30 easy + 40 medium + 30 difficult = **100 questions**.

# %% [markdown]
# ## Student instructions
#
# Solve all questions using banking scenarios. Practice classes, objects, instance/class attributes, methods, encapsulation, inheritance, polymorphism, composition, abstract classes, dataclasses, properties, protocols, and design patterns. Do not store real customer data, credentials, PINs, or complete card numbers. Each question includes a graduated hint but intentionally has no solution.
#
# **Recommended workflow:** write assumptions, implement the smallest correct function/class, test normal and edge cases, then explain your design.

# %% [markdown]
# ---
#
# ## Easy
#
# Fundamentals and direct applications.

# %% [markdown]
# ### Q1. Create a account class for banking case 1; use sample reference `ACC-1001` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, ref):
        self.ref = ref
        self.__balance = 0

    def deposit(self, amount):
        self.__balance += amount

a = Account("ACC-1001")
a.deposit(1000)
print(a.ref, a._Account__balance)
# Out:
# ACC-1001 1000

# %% [markdown]
# ### Q2. Add an initializer to accountholder for banking case 1; use sample reference `ACC-1002` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class AccountHolder:
    def __init__(self, name, ref):
        self.name = name
        self.ref = ref

h = AccountHolder("Customer", "ACC-1002")
print(h.name, h.ref)
# Out:
# Customer ACC-1002

# %% [markdown]
# ### Q3. Represent an transfer object for banking case 1; use sample reference `ACC-1003` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Transfer:
    def __init__(self, sender, receiver, amount):
        self.sender = sender
        self.receiver = receiver
        self.amount = amount

t = Transfer("ACC-1003", "ACC-2003", 500)
print(t.sender, t.receiver, t.amount)
# Out:
# ACC-1003 ACC-2003 500

# %% [markdown]
# ### Q4. Add a method that calculates line total for banking case 1; use sample reference `ACC-1004` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Transaction:
    def line_total(self, amount, fee):
        return amount + fee

t = Transaction()
print(t.line_total(1000, 20))
# Out:
# 1020

# %% [markdown]
# ### Q5. Use a class attribute for branch name for banking case 1; use sample reference `ACC-1005` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    branch_name = "Main Branch"

a = Account()
print(a.branch_name)
# Out:
# Main Branch

# %% [markdown]
# ### Q6. Write a readable __str__ method for banking case 1; use sample reference `ACC-1006` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, ref):
        self.ref = ref

    def __str__(self):
        return f"Account: {self.ref}"

print(Account("ACC-1006"))
# Out:
# Account: ACC-1006

# %% [markdown]
# ### Q7. Compare two account references with __eq__ for banking case 1; use sample reference `ACC-1007` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, ref):
        self.ref = ref

    def __eq__(self, other):
        return self.ref == other.ref

a = Account("ACC-1007")
b = Account("ACC-1007")
print(a == b)
# Out:
# True

# %% [markdown]
# ### Q8. Protect a amount with a property for banking case 1; use sample reference `ACC-1008` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, amount):
        self.amount = amount

    @property
    def amount(self):
        return self._amount

    @amount.setter
    def amount(self, value):
        if value < 0:
            raise ValueError("Amount cannot be negative")
        self._amount = value

a = Account(1000)
print(a.amount)
# Out:
# 1000

# %% [markdown]
# ### Q9. Create portfolio and add_item for banking case 1; use sample reference `ACC-1009` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Portfolio:
    def __init__(self):
        self.items = []

    def add_item(self, item):
        self.items.append(item)

p = Portfolio()
p.add_item("ACC-1009")
print(p.items)
# Out:
# ['ACC-1009']

# %% [markdown]
# ### Q10. Model a branchaddress for banking case 1; use sample reference `ACC-1010` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BranchAddress:
    def __init__(self, city, pincode):
        self.city = city
        self.pincode = pincode

a = BranchAddress("Bengaluru", 560001)
print(a.city, a.pincode)
# Out:
# Bengaluru 560001

# %% [markdown]
# ### Q11. Use a static method to validate account reference for banking case 1; use sample reference `ACC-1011` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    @staticmethod
    def valid_ref(ref):
        return ref.startswith("ACC-")

print(Account.valid_ref("ACC-1011"))
# Out:
# True

# %% [markdown]
# ### Q12. Use a class method as an alternate constructor for banking case 1; use sample reference `ACC-1012` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, ref):
        self.ref = ref

    @classmethod
    def create(cls, ref):
        return cls(ref)

a = Account.create("ACC-1012")
print(a.ref)
# Out:
# ACC-1012

# %% [markdown]
# ### Q13. Track object count for banking case 1; use sample reference `ACC-1013` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    count = 0

    def __init__(self, ref):
        self.ref = ref
        Account.count += 1

a = Account("ACC-1013")
print(Account.count)
# Out:
# 1

# %% [markdown]
# ### Q14. Model a loyaltyaccount for banking case 1; use sample reference `ACC-1014` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class LoyaltyAccount:
    def __init__(self, ref, points=0):
        self.ref = ref
        self.points = points

a = LoyaltyAccount("ACC-1014", 100)
print(a.ref, a.points)
# Out:
# ACC-1014 100

# %% [markdown]
# ### Q15. Create a supplier class for banking case 1; use sample reference `ACC-1015` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Supplier:
    def __init__(self, name):
        self.name = name

s = Supplier("Bank Supplier")
print(s.name)
# Out:
# Bank Supplier

# %% [markdown]
# ### Q16. Create a account class for banking case 2; use sample reference `ACC-1016` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, ref, balance=0):
        self.ref = ref
        self.balance = balance

a = Account("ACC-1016", 5000)
print(a.ref, a.balance)
# Out:
# ACC-1016 5000

# %% [markdown]
# ### Q17. Add an initializer to accountholder for banking case 2; use sample reference `ACC-1017` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class AccountHolder:
    def __init__(self, name, ref):
        self.name = name
        self.ref = ref

h = AccountHolder("Ravi", "ACC-1017")
print(h.name, h.ref)
# Out:
# Ravi ACC-1017

# %% [markdown]
# ### Q18. Represent an transfer object for banking case 2; use sample reference `ACC-1018` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Transfer:
    def __init__(self, from_acc, to_acc, amount):
        self.from_acc = from_acc
        self.to_acc = to_acc
        self.amount = amount

t = Transfer("ACC-1018", "ACC-1019", 1000)
print(t.amount)
# Out:
# 1000

# %% [markdown]
# ### Q19. Add a method that calculates line total for banking case 2; use sample reference `ACC-1019` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Line:
    def __init__(self, price, quantity):
        self.price = price
        self.quantity = quantity

    def line_total(self):
        return self.price * self.quantity

l = Line(100, 3)
print(l.line_total())
# Out:
# 300

# %% [markdown]
# ### Q20. Use a class attribute for branch name for banking case 2; use sample reference `ACC-1020` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    branch_name = "Bengaluru Branch"

    def __init__(self, ref):
        self.ref = ref

a = Account("ACC-1020")
print(a.ref, a.branch_name)
# Out:
# ACC-1020 Bengaluru Branch

# %% [markdown]
# ### Q21. Write a readable __str__ method for banking case 2; use sample reference `ACC-1021` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, ref):
        self.ref = ref

    def __str__(self):
        return self.ref

a = Account("ACC-1021")
print(a)
# Out:
# ACC-1021

# %% [markdown]
# ### Q22. Compare two account references with __eq__ for banking case 2; use sample reference `ACC-1022` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, ref):
        self.ref = ref

    def __eq__(self, other):
        return self.ref == other.ref

a = Account("ACC-1022")
b = Account("ACC-1022")
print(a == b)
# Out:
# True

# %% [markdown]
# ### Q23. Protect a amount with a property for banking case 2; use sample reference `ACC-1023` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, amount):
        self.amount = amount

    @property
    def amount(self):
        return self._amount

    @amount.setter
    def amount(self, value):
        self._amount = value

a = Account(1000)
print(a.amount)
# Out:
# 1000

# %% [markdown]
# ### Q24. Create portfolio and add_item for banking case 2; use sample reference `ACC-1024` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Portfolio:
    def __init__(self):
        self.items = []

    def add_item(self, item):
        self.items.append(item)

p = Portfolio()
p.add_item("ACC-1024")
print(p.items)
# Out:
# ['ACC-1024']

# %% [markdown]
# ### Q25. Model a branchaddress for banking case 2; use sample reference `ACC-1025` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BranchAddress:
    def __init__(self, city):
        self.city = city

a = BranchAddress("Bengaluru")
print(a.city)
# Out:
# Bengaluru

# %% [markdown]
# ### Q26. Use a static method to validate account reference for banking case 2; use sample reference `ACC-1026` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    @staticmethod
    def valid(ref):
        return ref.startswith("ACC-")

print(Account.valid("ACC-1026"))
# Out:
# True

# %% [markdown]
# ### Q27. Use a class method as an alternate constructor for banking case 2; use sample reference `ACC-1027` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, ref):
        self.ref = ref

    @classmethod
    def create(cls, ref):
        return cls(ref)

a = Account.create("ACC-1027")
print(a.ref)
# Out:
# ACC-1027

# %% [markdown]
# ### Q28. Track object count for banking case 2; use sample reference `ACC-1028` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    count = 0

    def __init__(self, ref):
        Account.count += 1

a = Account("ACC-1028")
print(Account.count)
# Out:
# 1

# %% [markdown]
# ### Q29. Model a loyaltyaccount for banking case 2; use sample reference `ACC-1029` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class LoyaltyAccount:
    def __init__(self, ref, points):
        self.ref = ref
        self.points = points

a = LoyaltyAccount("ACC-1029", 100)
print(a.ref, a.points)
# Out:
# ACC-1029 100

# %% [markdown]
# ### Q30. Create a supplier class for banking case 2; use sample reference `ACC-1030` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Supplier:
    def __init__(self, name):
        self.name = name

s = Supplier("Supplier")
print(s.name)
# Out:
# Supplier

# %% [markdown]
# ---
#
# ## Medium
#
# Reusable components and multi-step workflows.

# %% [markdown]
# ### Q31. Inherit perishableaccount from account for banking case 1; use sample reference `ACC-1031` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, ref, balance=0):
        self.ref = ref
        self.balanceance = balance

    def show(self):
        print(self.ref, self.balanceance)


class PerishableAccount(Account):
    def __init__(self, ref, balance=0, expiry="2026-12-31"):
        super().__init__(ref, balance)
        self.expiry = expiry

    def show(self):
        print(self.ref, self.balanceance, self.expiry)


a = PerishableAccount("ACC-1031", 5000)
a.show()
# Out:
# ACC-1031 5000 2026-12-31

# %% [markdown]
# ### Q32. Override a discount method for banking case 1; use sample reference `ACC-1032` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def discount(self):
        return 5


class PremiumAccount(Account):
    def discount(self):
        return 10


a = PremiumAccount()
print("Discount:", a.discount(), "%")
# Out:
# Discount: 10 %

# %% [markdown]
# ### Q33. Use polymorphic payment processors for banking case 1; use sample reference `ACC-1033` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class CardPayment:
    def pay(self, amount):
        print("Card payment:", amount)


class UPIPayment:
    def pay(self, amount):
        print("UPI payment:", amount)


def process(payment, amount):
    payment.pay(amount)


process(CardPayment(), 1000)
process(UPIPayment(), 2000)
# Out:
# Card payment: 1000
# UPI payment: 2000

# %% [markdown]
# ### Q34. Compose transfer from transferline objects for banking case 1; use sample reference `ACC-1034` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class TransferLine:
    def __init__(self, from_acc, to_acc, amount):
        self.from_acc = from_acc
        self.to_acc = to_acc
        self.amount = amount


class Transfer:
    def __init__(self, reference):
        self.reference = reference
        self.lines = []

    def add_line(self, line):
        self.lines.append(line)

    def show(self):
        print("Transfer:", self.reference)
        for line in self.lines:
            print(line.from_acc, "->", line.to_acc, line.amount)


t = Transfer("ACC-1034")
t.add_line(TransferLine("ACC-1034", "ACC-2001", 1500))
t.show()
# Out:
# Transfer: ACC-1034
# ACC-1034 -> ACC-2001 1500

# %% [markdown]
# ### Q35. Define an abstract paymentmethod for banking case 1; use sample reference `ACC-1035` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from abc import ABC, abstractmethod

class PaymentMethod(ABC):
    @abstractmethod
    def pay(self, amount):
        pass


class BankPayment(PaymentMethod):
    def pay(self, amount):
        print("Bank payment:", amount)


p = BankPayment()
p.pay(2500)
# Out:
# Bank payment: 2500

# %% [markdown]
# ### Q36. Use a dataclass for inventoryrecord for banking case 1; use sample reference `ACC-1036` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from dataclasses import dataclass

@dataclass
class InventoryRecord:
    reference: str
    item: str
    quantity: int


record = InventoryRecord("ACC-1036", "ATM Card", 20)
print(record)
# Out:
# InventoryRecord(reference='ACC-1036', item='ATM Card', quantity=20)

# %% [markdown]
# ### Q37. Implement a custom iterator for portfolio for banking case 1; use sample reference `ACC-1037` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Portfolio:
    def __init__(self, accounts):
        self.accounts = accounts

    def __iter__(self):
        return iter(self.accounts)


p = Portfolio(["ACC-1037", "ACC-2001", "ACC-2002"])

for account in p:
    print(account)
# Out:
# ACC-1037
# ACC-2001
# ACC-2002

# %% [markdown]
# ### Q38. Use multiple inheritance carefully for timestampeditem for banking case 1; use sample reference `ACC-1038` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from datetime import datetime

class Item:
    def __init__(self, ref):
        self.ref = ref


class Timestamped:
    def __init__(self):
        self.time = datetime.now()


class TimestampedItem(Item, Timestamped):
    def __init__(self, ref):
        Item.__init__(self, ref)
        Timestamped.__init__(self)

    def show(self):
        print(self.ref, self.time)


x = TimestampedItem("ACC-1038")
x.show()
# Out:
# ACC-1038 2026-09-11 08:31:51.063654

# %% [markdown]
# ### Q39. Create a account factory for banking case 1; use sample reference `ACC-1039` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, ref):
        self.ref = ref


class SavingsAccount(Account):
    pass


class CurrentAccount(Account):
    pass


class AccountFactory:
    @staticmethod
    def create(kind, ref):
        if kind == "savings":
            return SavingsAccount(ref)
        return CurrentAccount(ref)


a = AccountFactory.create("savings", "ACC-1039")
print(type(a).__name__, a.ref)
# Out:
# SavingsAccount ACC-1039

# %% [markdown]
# ### Q40. Apply a strategy for interest offers for banking case 1; use sample reference `ACC-1040` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class RegularInterest:
    def calculate(self, balance):
        return balance * 0.05


class PremiumInterest:
    def calculate(self, balance):
        return balance * 0.08


class Account:
    def __init__(self, ref, balance, strategy):
        self.ref = ref
        self.balanceance = balance
        self.strategy = strategy

    def interest(self):
        return self.strategy.calculate(self.balanceance)


a = Account("ACC-1040", 10000, PremiumInterest())
print("Interest:", a.interest())
# Out:
# Interest: 800.0

# %% [markdown]
# ### Q41. Encapsulate balance reservation for banking case 1; use sample reference `ACC-1041` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, ref, balance):
        self.ref = ref
        self.__balance = balance
        self.__reserved = 0

    def reserve(self, amount):
        if amount <= self.__balance - self.__reserved:
            self.__reserved += amount
            return True
        return False

    def available_balance(self):
        return self.__balance - self.__reserved


a = Account("ACC-1041", 5000)
print(a.reserve(1000))
print(a.available_balance())
# Out:
# True
# 4000

# %% [markdown]
# ### Q42. Model aggregation between branch and employees for banking case 1; use sample reference `ACC-1042` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Employee:
    def __init__(self, name):
        self.name = name


class Branch:
    def __init__(self, name):
        self.name = name
        self.employees = []

    def add_employee(self, employee):
        self.employees.append(employee)


e1 = Employee("Ravi")
e2 = Employee("Anu")

branch = Branch("Main Branch")
branch.add_employee(e1)
branch.add_employee(e2)

print(branch.name)
for e in branch.employees:
    print(e.name)
# Out:
# Main Branch
# Ravi
# Anu

# %% [markdown]
# ### Q43. Serialize an transfer to a dictionary for banking case 1; use sample reference `ACC-1043` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Transfer:
    def __init__(self, ref, sender, receiver, amount):
        self.ref = ref
        self.sender = sender
        self.receiver = receiver
        self.amount = amount

    def to_dict(self):
        return {
            "reference": self.ref,
            "sender": self.sender,
            "receiver": self.receiver,
            "amount": self.amount
        }


t = Transfer("ACC-1043", "A101", "A102", 5000)
print(t.to_dict())
# Out:
# {'reference': 'ACC-1043', 'sender': 'A101', 'receiver': 'A102', 'amount': 5000}

# %% [markdown]
# ### Q44. Implement a repository abstraction for banking case 1; use sample reference `ACC-1044` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class AccountRepository:
    def __init__(self):
        self.accounts = {}

    def save(self, account):
        self.accounts[account.ref] = account

    def find(self, ref):
        return self.accounts.get(ref)


class Account:
    def __init__(self, ref):
        self.ref = ref


repo = AccountRepository()
account = Account("ACC-1044")

repo.save(account)
print(repo.find("ACC-1044").ref)
# Out:
# ACC-1044

# %% [markdown]
# ### Q45. Apply dependency injection to checkout for banking case 1; use sample reference `ACC-1045` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Payment:
    def pay(self, amount):
        print("Paid:", amount)


class Checkout:
    def __init__(self, payment):
        self.payment = payment

    def checkout(self, amount):
        self.payment.pay(amount)


payment = Payment()
checkout = Checkout(payment)

checkout.checkout(1000)
# Out:
# Paid: 1000

# %% [markdown]
# ### Q46. Inherit perishableaccount from account for banking case 2; use sample reference `ACC-1046` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, ref, balance):
        self.ref = ref
        self.balanceance = balance

    def show(self):
        print(self.ref, self.balanceance)


class PerishableAccount(Account):
    def __init__(self, ref, balance, expiry):
        super().__init__(ref, balance)
        self.expiry = expiry

    def show(self):
        super().show()
        print("Expiry:", self.expiry)


a = PerishableAccount("ACC-1046", 5000, "2026-12-31")
a.show()
# Out:
# ACC-1046 5000
# Expiry: 2026-12-31

# %% [markdown]
# ### Q47. Override a discount method for banking case 2; use sample reference `ACC-1047` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def discount(self, amount):
        return amount * 0.05


class PremiumAccount(Account):
    def discount(self, amount):
        return amount * 0.10


a = PremiumAccount()
print("Discount:", a.discount(1000))
# Out:
# Discount: 100.0

# %% [markdown]
# ### Q48. Use polymorphic payment processors for banking case 2; use sample reference `ACC-1048` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class CardPayment:
    def pay(self, amount):
        print("Card payment:", amount)


class UpiPayment:
    def pay(self, amount):
        print("UPI payment:", amount)


def process_payment(payment, amount):
    payment.pay(amount)


process_payment(CardPayment(), 1000)
process_payment(UpiPayment(), 2000)
# Out:
# Card payment: 1000
# UPI payment: 2000

# %% [markdown]
# ### Q49. Compose transfer from transferline objects for banking case 2; use sample reference `ACC-1049` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class TransferLine:
    def __init__(self, account, amount):
        self.account = account
        self.amount = amount


class Transfer:
    def __init__(self, ref):
        self.ref = ref
        self.lines = []

    def add_line(self, line):
        self.lines.append(line)

    def total(self):
        return sum(line.amount for line in self.lines)


t = Transfer("ACC-1049")
t.add_line(TransferLine("A101", 1000))
t.add_line(TransferLine("A102", 2000))

print("Total:", t.total())
# Out:
# Total: 3000

# %% [markdown]
# ### Q50. Define an abstract paymentmethod for banking case 2; use sample reference `ACC-1050` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from abc import ABC, abstractmethod


class PaymentMethod(ABC):
    @abstractmethod
    def pay(self, amount):
        pass


class CardPayment(PaymentMethod):
    def pay(self, amount):
        print("Card payment:", amount)


class UpiPayment(PaymentMethod):
    def pay(self, amount):
        print("UPI payment:", amount)


p = UpiPayment()
p.pay(1500)
# Out:
# UPI payment: 1500

# %% [markdown]
# ### Q51. Use a dataclass for inventoryrecord for banking case 2; use sample reference `ACC-1051` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from dataclasses import dataclass

@dataclass
class InventoryRecord:
    reference: str
    item: str
    quantity: int

record = InventoryRecord("ACC-1051", "ATM Cards", 100)

print(record)
# Out:
# InventoryRecord(reference='ACC-1051', item='ATM Cards', quantity=100)

# %% [markdown]
# ### Q52. Implement a custom iterator for portfolio for banking case 2; use sample reference `ACC-1052` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Portfolio:
    def __init__(self, accounts):
        self.accounts = accounts

    def __iter__(self):
        return iter(self.accounts)

portfolio = Portfolio(["ACC-1052", "ACC-1053", "ACC-1054"])

for account in portfolio:
    print(account)
# Out:
# ACC-1052
# ACC-1053
# ACC-1054

# %% [markdown]
# ### Q53. Use multiple inheritance carefully for timestampeditem for banking case 2; use sample reference `ACC-1053` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from datetime import datetime

class Item:
    def __init__(self, reference):
        self.reference = reference

class Timestamped:
    def __init__(self):
        self.time = datetime.now()

class TimestampedItem(Item, Timestamped):
    def __init__(self, reference):
        Item.__init__(self, reference)
        Timestamped.__init__(self)

obj = TimestampedItem("ACC-1053")

print(obj.reference)
print(obj.time)
# Out:
# ACC-1053
# 2026-09-11 08:31:51.318524

# %% [markdown]
# ### Q54. Create a account factory for banking case 2; use sample reference `ACC-1054` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, reference):
        self.reference = reference

class SavingsAccount(Account):
    pass

class CurrentAccount(Account):
    pass

class AccountFactory:
    @staticmethod
    def create(account_type, reference):
        if account_type == "savings":
            return SavingsAccount(reference)
        return CurrentAccount(reference)

account = AccountFactory.create("savings", "ACC-1054")

print(type(account).__name__)
print(account.reference)
# Out:
# SavingsAccount
# ACC-1054

# %% [markdown]
# ### Q55. Apply a strategy for interest offers for banking case 2; use sample reference `ACC-1055` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class RegularInterest:
    def calculate(self, amount):
        return amount * 0.04

class PremiumInterest:
    def calculate(self, amount):
        return amount * 0.06

class InterestOffer:
    def __init__(self, strategy):
        self.strategy = strategy

    def get_interest(self, amount):
        return self.strategy.calculate(amount)

offer = InterestOffer(PremiumInterest())

print(offer.get_interest(10000))
# Out:
# 600.0

# %% [markdown]
# ### Q56. Encapsulate balance reservation for banking case 2; use sample reference `ACC-1056` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, reference, balance):
        self.reference = reference
        self.__balance = balance
        self.__reserved = 0

    def reserve(self, amount):
        if amount <= self.__balance - self.__reserved:
            self.__reserved += amount
            return True
        return False

    def available_balance(self):
        return self.__balance - self.__reserved

account = Account("ACC-1056", 5000)

print(account.reserve(1000))
print(account.available_balance())
# Out:
# True
# 4000

# %% [markdown]
# ### Q57. Model aggregation between branch and employees for banking case 2; use sample reference `ACC-1057` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Employee:
    def __init__(self, name):
        self.name = name

class Branch:
    def __init__(self, name):
        self.name = name
        self.employees = []

    def add_employee(self, employee):
        self.employees.append(employee)

branch = Branch("Bengaluru")
branch.add_employee(Employee("Ravi"))
branch.add_employee(Employee("Anu"))

print(branch.name)

for employee in branch.employees:
    print(employee.name)
# Out:
# Bengaluru
# Ravi
# Anu

# %% [markdown]
# ### Q58. Serialize an transfer to a dictionary for banking case 2; use sample reference `ACC-1058` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Transfer:
    def __init__(self, reference, sender, receiver, amount):
        self.reference = reference
        self.sender = sender
        self.receiver = receiver
        self.amount = amount

    def to_dict(self):
        return {
            "reference": self.reference,
            "sender": self.sender,
            "receiver": self.receiver,
            "amount": self.amount
        }

transfer = Transfer("ACC-1058", "A101", "A102", 2000)

print(transfer.to_dict())
# Out:
# {'reference': 'ACC-1058', 'sender': 'A101', 'receiver': 'A102', 'amount': 2000}

# %% [markdown]
# ### Q59. Implement a repository abstraction for banking case 2; use sample reference `ACC-1059` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from abc import ABC, abstractmethod

class AccountRepository(ABC):
    @abstractmethod
    def save(self, account):
        pass

class MemoryRepository(AccountRepository):
    def __init__(self):
        self.accounts = {}

    def save(self, account):
        self.accounts[account.reference] = account

class Account:
    def __init__(self, reference):
        self.reference = reference

repo = MemoryRepository()
account = Account("ACC-1059")

repo.save(account)

print(repo.accounts["ACC-1059"].reference)
# Out:
# ACC-1059

# %% [markdown]
# ### Q60. Apply dependency injection to checkout for banking case 2; use sample reference `ACC-1060` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Payment:
    def pay(self, amount):
        print("Paid:", amount)

class Checkout:
    def __init__(self, payment):
        self.payment = payment

    def checkout(self, amount):
        self.payment.pay(amount)

payment = Payment()
checkout = Checkout(payment)

checkout.checkout(1500)
# Out:
# Paid: 1500

# %% [markdown]
# ### Q61. Inherit perishableaccount from account for banking case 3; use sample reference `ACC-1061` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, ref, balance=0):
        self.ref = ref
        self.balanceance = balance

    def deposit(self, amount):
        self.balanceance += amount


class PerishableAccount(Account):
    def __init__(self, ref, balance=0, expiry_days=30):
        super().__init__(ref, balance)
        self.expiry_days = expiry_days

    def show(self):
        print(self.ref, self.balanceance, self.expiry_days)


a = PerishableAccount("ACC-1061", 5000, 30)
a.deposit(1000)
a.show()
# Out:
# ACC-1061 6000 30

# %% [markdown]
# ### Q62. Override a discount method for banking case 3; use sample reference `ACC-1062` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, ref, amount):
        self.ref = ref
        self.amount = amount

    def discount(self):
        return self.amount * 0.05


class PremiumAccount(Account):
    def discount(self):
        return self.amount * 0.10


a = PremiumAccount("ACC-1062", 10000)
print("Discount:", a.discount())
# Out:
# Discount: 1000.0

# %% [markdown]
# ### Q63. Use polymorphic payment processors for banking case 3; use sample reference `ACC-1063` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class CardPayment:
    def pay(self, amount):
        print("Card payment:", amount)


class UpiPayment:
    def pay(self, amount):
        print("UPI payment:", amount)


class PaymentProcessor:
    def process(self, payment, amount):
        payment.pay(amount)


p = PaymentProcessor()

p.process(CardPayment(), 2000)
p.process(UpiPayment(), 3000)
# Out:
# Card payment: 2000
# UPI payment: 3000

# %% [markdown]
# ### Q64. Compose transfer from transferline objects for banking case 3; use sample reference `ACC-1064` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class TransferLine:
    def __init__(self, account, amount):
        self.account = account
        self.amount = amount

    def show(self):
        print(self.account, self.amount)


class Transfer:
    def __init__(self, ref):
        self.ref = ref
        self.lines = []

    def add_line(self, line):
        self.lines.append(line)

    def show(self):
        print("Transfer:", self.ref)
        for line in self.lines:
            line.show()


t = Transfer("ACC-1064")
t.add_line(TransferLine("ACC-1001", 5000))
t.add_line(TransferLine("ACC-1002", 5000))

t.show()
# Out:
# Transfer: ACC-1064
# ACC-1001 5000
# ACC-1002 5000

# %% [markdown]
# ### Q65. Define an abstract paymentmethod for banking case 3; use sample reference `ACC-1065` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from abc import ABC, abstractmethod

class PaymentMethod(ABC):
    @abstractmethod
    def pay(self, amount):
        pass


class Card(PaymentMethod):
    def pay(self, amount):
        print("Paid by card:", amount)


class UPI(PaymentMethod):
    def pay(self, amount):
        print("Paid by UPI:", amount)


p = Card()
p.pay(2500)
# Out:
# Paid by card: 2500

# %% [markdown]
# ### Q66. Use a dataclass for inventoryrecord for banking case 3; use sample reference `ACC-1066` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from dataclasses import dataclass

@dataclass
class InventoryRecord:
    ref: str
    item: str
    quantity: int
    price: float

    def total(self):
        return self.quantity * self.price


record = InventoryRecord("ACC-1066", "Passbook", 5, 100)
print(record)
print("Total:", record.total())
# Out:
# InventoryRecord(ref='ACC-1066', item='Passbook', quantity=5, price=100)
# Total: 500

# %% [markdown]
# ### Q67. Implement a custom iterator for portfolio for banking case 3; use sample reference `ACC-1067` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Portfolio:
    def __init__(self, accounts):
        self.accounts = accounts

    def __iter__(self):
        return iter(self.accounts)


p = Portfolio([
    "ACC-1067-A",
    "ACC-1067-B",
    "ACC-1067-C"
])

for account in p:
    print(account)
# Out:
# ACC-1067-A
# ACC-1067-B
# ACC-1067-C

# %% [markdown]
# ### Q68. Use multiple inheritance carefully for timestampeditem for banking case 3; use sample reference `ACC-1068` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from datetime import datetime

class Item:
    def __init__(self, ref):
        self.ref = ref


class Timestamped:
    def __init__(self):
        self.created = datetime.now()


class TimestampedItem(Item, Timestamped):
    def __init__(self, ref):
        Item.__init__(self, ref)
        Timestamped.__init__(self)

    def show(self):
        print(self.ref)
        print(self.created)


item = TimestampedItem("ACC-1068")
item.show()
# Out:
# ACC-1068
# 2026-09-11 08:31:51.539857

# %% [markdown]
# ### Q69. Create a account factory for banking case 3; use sample reference `ACC-1069` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, ref, account_type):
        self.ref = ref
        self.account_type = account_type


class AccountFactory:
    @staticmethod
    def create(ref, account_type):
        return Account(ref, account_type)


a = AccountFactory.create("ACC-1069", "Savings")

print(a.ref)
print(a.account_type)
# Out:
# ACC-1069
# Savings

# %% [markdown]
# ### Q70. Apply a strategy for interest offers for banking case 3; use sample reference `ACC-1070` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class NormalInterest:
    def calculate(self, balance):
        return balance * 0.04


class PremiumInterest:
    def calculate(self, balance):
        return balance * 0.06


class InterestOffer:
    def __init__(self, strategy):
        self.strategy = strategy

    def calculate(self, balance):
        return self.strategy.calculate(balance)


offer = InterestOffer(PremiumInterest())

print("Interest:", offer.calculate(10000))
# Out:
# Interest: 600.0

# %% [markdown]
# ---
#
# ## Difficult
#
# Architecture, edge cases, and end-to-end banking systems.

# %% [markdown]
# ### Q71. Design an extensible pricing engine for banking case 1; use sample reference `ACC-1071` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Pricing:
    def price(self, amount):
        return amount

class DiscountPricing(Pricing):
    def price(self, amount):
        return amount * 0.90

class PricingEngine:
    def __init__(self, strategy):
        self.strategy = strategy

    def calculate(self, amount):
        return self.strategy.price(amount)

engine = PricingEngine(DiscountPricing())
print(engine.calculate(1000))   # 900.0
# Out:
# 900.0

# %% [markdown]
# ### Q72. Implement an observer for low balance for banking case 1; use sample reference `ACC-1072` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, balance):
        self.balanceance = balance
        self.observers = []

    def add_observer(self, observer):
        self.observers.append(observer)

    def withdraw(self, amount):
        self.balanceance -= amount
        if self.balanceance < 1000:
            for observer in self.observers:
                observer(self.balanceance)

def alert(balance):
    print("Low balance:", balance)

a = Account(2000)
a.add_observer(alert)
a.withdraw(1200)
# Out:
# Low balance: 800

# %% [markdown]
# ### Q73. Build a state machine for transfer status for banking case 1; use sample reference `ACC-1073` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Transfer:
    def __init__(self):
        self.status = "Pending"

    def process(self):
        if self.status == "Pending":
            self.status = "Processing"
        elif self.status == "Processing":
            self.status = "Completed"

t = Transfer()
t.process()
t.process()
print(t.status)
# Out:
# Completed

# %% [markdown]
# ### Q74. Create an immutable money value object for banking case 1; use sample reference `ACC-1074` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from dataclasses import dataclass

@dataclass(frozen=True)
class Money:
    amount: float
    currency: str

money = Money(1000, "INR")
print(money)
# Out:
# Money(amount=1000, currency='INR')

# %% [markdown]
# ### Q75. Implement a unit-of-work transaction for banking case 1; use sample reference `ACC-1075` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, balance):
        self.balance = balance

class UnitOfWork:
    def transfer(self, sender, receiver, amount):
        if sender.balance >= amount:
            sender.balance -= amount
            receiver.balance += amount
            return "Committed"
        return "Failed"

a = Account(5000)
b = Account(1000)

uow = UnitOfWork()
print(uow.transfer(a, b, 1000))
print(a.balance, b.balance)
# Out:
# Committed
# 4000 2000

# %% [markdown]
# ### Q76. Separate domain and infrastructure layers for banking case 1; use sample reference `ACC-1076` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, balance):
        self.balance = balance

class AccountRepository:
    def save(self, account):
        print("Account saved")

account = Account(5000)
repository = AccountRepository()

account.balance += 1000
repository.save(account)

print(account.balance)
# Out:
# Account saved
# 6000

# %% [markdown]
# ### Q77. Design a plugin-ready payment architecture for banking case 1; use sample reference `ACC-1077` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Payment:
    def pay(self, amount):
        raise NotImplementedError

class CardPayment(Payment):
    def pay(self, amount):
        return f"Card payment: {amount}"

class UPIPayment(Payment):
    def pay(self, amount):
        return f"UPI payment: {amount}"

class PaymentProcessor:
    def __init__(self, payment):
        self.payment = payment

    def process(self, amount):
        return self.payment.pay(amount)

processor = PaymentProcessor(UPIPayment())
print(processor.process(1000))
# Out:
# UPI payment: 1000

# %% [markdown]
# ### Q78. Implement a descriptor for positive amounts for banking case 1; use sample reference `ACC-1078` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PositiveAmount:
    def __set_name__(self, owner, name):
        self.name = name

    def __get__(self, obj, owner):
        return obj.__dict__[self.name]

    def __set__(self, obj, value):
        if value <= 0:
            raise ValueError("Amount must be positive")
        obj.__dict__[self.name] = value

class Account:
    amount = PositiveAmount()

    def __init__(self, amount):
        self.amount = amount

a = Account(1000)
print(a.amount)
# Out:
# 1000

# %% [markdown]
# ### Q79. Use cooperative inheritance with super for banking case 1; use sample reference `ACC-1079` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, ref):
        self.ref = ref

class SavingsAccount(Account):
    def __init__(self, ref, interest):
        super().__init__(ref)
        self.interest = interest

class PremiumAccount(SavingsAccount):
    def __init__(self, ref, interest, bonus):
        super().__init__(ref, interest)
        self.bonus = bonus

a = PremiumAccount("ACC-1079", 5, 2)
print(a.ref, a.interest, a.bonus)
# Out:
# ACC-1079 5 2

# %% [markdown]
# ### Q80. Refactor a god object using solid for banking case 1; use sample reference `ACC-1080` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, balance):
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount

class TransferService:
    def transfer(self, sender, receiver, amount):
        if sender.balance >= amount:
            sender.balance -= amount
            receiver.balance += amount
            return True
        return False

class AccountReport:
    def show(self, account):
        print("Balance:", account.balance)

a = Account(5000)
b = Account(1000)

TransferService().transfer(a, b, 1000)
AccountReport().show(a)
# Out:
# Balance: 4000

# %% [markdown]
# ### Q81. Design an extensible pricing engine for banking case 2; use sample reference `ACC-1081` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Pricing:
    def price(self, amount):
        return amount

class PremiumPricing(Pricing):
    def price(self, amount):
        return amount * 0.90

class PricingEngine:
    def __init__(self, strategy):
        self.strategy = strategy

    def calculate(self, amount):
        return self.strategy.price(amount)

engine = PricingEngine(PremiumPricing())
print(engine.calculate(1000))
# Out:
# 900.0

# %% [markdown]
# ### Q82. Implement an observer for low balance for banking case 2; use sample reference `ACC-1082` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, balance):
        self.balanceance = balance
        self.observers = []

    def add_observer(self, observer):
        self.observers.append(observer)

    def withdraw(self, amount):
        self.balanceance -= amount
        if self.balanceance < 500:
            for observer in self.observers:
                observer(self.balanceance)

def alert(balance):
    print("Low balance:", balance)

a = Account(1000)
a.add_observer(alert)
a.withdraw(600)
# Out:
# Low balance: 400

# %% [markdown]
# ### Q83. Build a state machine for transfer status for banking case 2; use sample reference `ACC-1083` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Transfer:
    def __init__(self, ref):
        self.ref = ref
        self.status = "Pending"

    def change_status(self, status):
        allowed = {
            "Pending": ["Processing"],
            "Processing": ["Completed", "Failed"],
            "Completed": [],
            "Failed": []
        }
        if status in allowed[self.status]:
            self.status = status
        else:
            print("Invalid transition")

t = Transfer("ACC-1083")
t.change_status("Processing")
t.change_status("Completed")
print(t.ref, t.status)
# Out:
# ACC-1083 Completed

# %% [markdown]
# ### Q84. Create an immutable money value object for banking case 2; use sample reference `ACC-1084` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from dataclasses import dataclass

@dataclass(frozen=True)
class Money:
    amount: float
    currency: str

money = Money(1000, "INR")
print(money)
# Out:
# Money(amount=1000, currency='INR')

# %% [markdown]
# ### Q85. Implement a unit-of-work transaction for banking case 2; use sample reference `ACC-1085` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, balance):
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount

    def withdraw(self, amount):
        if self.balance >= amount:
            self.balance -= amount
            return True
        return False

class Transaction:
    def transfer(self, sender, receiver, amount):
        if sender.withdraw(amount):
            receiver.deposit(amount)
            return "Success"
        return "Failed"

a = Account(5000)
b = Account(1000)

t = Transaction()
print(t.transfer(a, b, 1000))
print(a.balance, b.balance)
# Out:
# Success
# 4000 2000

# %% [markdown]
# ### Q86. Separate domain and infrastructure layers for banking case 2; use sample reference `ACC-1086` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, ref, balance):
        self.ref = ref
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount

class AccountRepository:
    def save(self, account):
        print("Saved:", account.ref)

account = Account("ACC-1086", 5000)

repo = AccountRepository()
account.deposit(1000)
repo.save(account)

print(account.balance)
# Out:
# Saved: ACC-1086
# 6000

# %% [markdown]
# ### Q87. Design a plugin-ready payment architecture for banking case 2; use sample reference `ACC-1087` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Payment:
    def pay(self, amount):
        raise NotImplementedError

class CardPayment(Payment):
    def pay(self, amount):
        return f"Card payment: {amount}"

class UPIPayment(Payment):
    def pay(self, amount):
        return f"UPI payment: {amount}"

class PaymentSystem:
    def __init__(self, method):
        self.method = method

    def make_payment(self, amount):
        return self.method.pay(amount)

system = PaymentSystem(UPIPayment())
print(system.make_payment(1000))
# Out:
# UPI payment: 1000

# %% [markdown]
# ### Q88. Implement a descriptor for positive amounts for banking case 2; use sample reference `ACC-1088` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PositiveAmount:
    def __set_name__(self, owner, name):
        self.name = "_" + name

    def __get__(self, obj, owner):
        return getattr(obj, self.name)

    def __set__(self, obj, value):
        if value <= 0:
            raise ValueError("Amount must be positive")
        setattr(obj, self.name, value)

class Account:
    amount = PositiveAmount()

    def __init__(self, amount):
        self.amount = amount

a = Account(1000)
print(a.amount)
# Out:
# 1000

# %% [markdown]
# ### Q89. Use cooperative inheritance with super for banking case 2; use sample reference `ACC-1089` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, ref):
        self.ref = ref

class Customer:
    def __init__(self, name, **kwargs):
        super().__init__(**kwargs)
        self.name = name

class BankAccount(Customer, Account):
    def __init__(self, name, ref):
        super().__init__(name=name, ref=ref)

a = BankAccount("Ravi", "ACC-1089")
print(a.name, a.ref)
# Out:
# Ravi ACC-1089

# %% [markdown]
# ### Q90. Refactor a god object using solid for banking case 2; use sample reference `ACC-1090` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, ref, balance):
        self.ref = ref
        self.balance = balance

class AccountService:
    def deposit(self, account, amount):
        account.balance += amount

class AccountRepository:
    def save(self, account):
        print("Saved:", account.ref)

account = Account("ACC-1090", 5000)

service = AccountService()
repo = AccountRepository()

service.deposit(account, 1000)
repo.save(account)

print(account.balance)
# Out:
# Saved: ACC-1090
# 6000

# %% [markdown]
# ### Q91. Design an extensible pricing engine for banking case 3; use sample reference `ACC-1091` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class StandardPrice:
    def price(self, amount):
        return amount

class PremiumPrice:
    def price(self, amount):
        return amount * 0.9

class PricingEngine:
    def __init__(self, strategy):
        self.strategy = strategy

    def calculate(self, amount):
        return self.strategy.price(amount)

engine = PricingEngine(PremiumPrice())
print(engine.calculate(1000))
# Out:
# 900.0

# %% [markdown]
# ### Q92. Implement an observer for low balance for banking case 3; use sample reference `ACC-1092` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Alert:
    def update(self, balance):
        print("Low balance:", balance)

class Account:
    def __init__(self, balance):
        self.balanceance = balance
        self.observers = []

    def add_observer(self, observer):
        self.observers.append(observer)

    def withdraw(self, amount):
        self.balanceance -= amount
        if self.balanceance < 500:
            for o in self.observers:
                o.update(self.balanceance)

a = Account(1000)
a.add_observer(Alert())
a.withdraw(600)
# Out:
# Low balance: 400

# %% [markdown]
# ### Q93. Build a state machine for transfer status for banking case 3; use sample reference `ACC-1093` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Transfer:
    def __init__(self):
        self.status = "Pending"

    def complete(self):
        if self.status == "Pending":
            self.status = "Completed"

    def fail(self):
        if self.status == "Pending":
            self.status = "Failed"

t = Transfer()
t.complete()
print(t.status)
# Out:
# Completed

# %% [markdown]
# ### Q94. Create an immutable money value object for banking case 3; use sample reference `ACC-1094` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from dataclasses import dataclass

@dataclass(frozen=True)
class Money:
    amount: float
    currency: str

m = Money(1000, "INR")
print(m)
# Out:
# Money(amount=1000, currency='INR')

# %% [markdown]
# ### Q95. Implement a unit-of-work transaction for banking case 3; use sample reference `ACC-1095` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class UnitOfWork:
    def __enter__(self):
        print("Transaction started")
        return self

    def __exit__(self, exc_type, exc, tb):
        if exc:
            print("Rollback")
        else:
            print("Commit")

with UnitOfWork():
    print("Transfer ACC-1095")
# Out:
# Transaction started
# Transfer ACC-1095
# Commit

# %% [markdown]
# ### Q96. Separate domain and infrastructure layers for banking case 3; use sample reference `ACC-1096` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, ref, balance):
        self.ref = ref
        self.balanceance = balance

class AccountRepository:
    def save(self, account):
        print("Saved:", account.ref)

account = Account("ACC-1096", 5000)
repo = AccountRepository()
repo.save(account)
# Out:
# Saved: ACC-1096

# %% [markdown]
# ### Q97. Design a plugin-ready payment architecture for banking case 3; use sample reference `ACC-1097` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Payment:
    def pay(self, amount):
        raise NotImplementedError

class CardPayment(Payment):
    def pay(self, amount):
        return f"Card payment: {amount}"

class UPIPayment(Payment):
    def pay(self, amount):
        return f"UPI payment: {amount}"

class PaymentSystem:
    def __init__(self, method):
        self.method = method

    def process(self, amount):
        return self.method.pay(amount)

p = PaymentSystem(UPIPayment())
print(p.process(1000))
# Out:
# UPI payment: 1000

# %% [markdown]
# ### Q98. Implement a descriptor for positive amounts for banking case 3; use sample reference `ACC-1098` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PositiveAmount:
    def __get__(self, obj, owner):
        return obj._amount

    def __set__(self, obj, value):
        if value <= 0:
            raise ValueError("Amount must be positive")
        obj._amount = value

class Account:
    amount = PositiveAmount()

    def __init__(self, amount):
        self.amount = amount

a = Account(1000)
print(a.amount)
# Out:
# 1000

# %% [markdown]
# ### Q99. Use cooperative inheritance with super for banking case 3; use sample reference `ACC-1099` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, ref, **kwargs):
        super().__init__(**kwargs)
        self.ref = ref

class Customer(Account):
    def __init__(self, name, **kwargs):
        super().__init__(**kwargs)
        self.name = name

c = Customer(name="Ravi", ref="ACC-1099")
print(c.ref, c.name)
# Out:
# ACC-1099 Ravi

# %% [markdown]
# ### Q100. Refactor a god object using solid for banking case 3; use sample reference `ACC-1100` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, balance):
        self.balance = balance

class Deposit:
    def add(self, account, amount):
        account.balance += amount

class Withdrawal:
    def withdraw(self, account, amount):
        if amount <= account.balance:
            account.balance -= amount

a = Account(1000)

Deposit().add(a, 500)
Withdrawal().withdraw(a, 200)

print(a.balance)
# Out:
# 1300
